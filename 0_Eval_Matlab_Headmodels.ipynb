# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt

import os
import numpy as np
import scipy
import matplotlib.pyplot as plt
import sys; sys.path.insert(0, r"C:\Users\lukas\OneDrive\Dokumente\projects\invert")

from invert import Solver

n_sources = 3

# %%
headmodels = [
    "headmodel_surf_openmeeg_MEG_groundtruth_constrained.mat",
    "headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained.mat",
]
base_path = r"D:\data\flex_ssm\headmodels_subj04NN_MEGEEG_50000_correct"

forward_models = []
leadfields = []
for headmodel in headmodels:
    leadfield = scipy.io.loadmat(os.path.join(base_path, "headmodels", headmodel))["Gain"]
    leadfield /= leadfield.std(axis=0)
    leadfield = leadfield.astype(np.float32)
    leadfields.append(leadfield)
    is_groundtruth = "groundtruth" in headmodel
    forward_model = dict(leadfield=leadfield, headmodel=headmodel.split(".")[0], groundtruth=is_groundtruth, n_sources=leadfield.shape[1])
    forward_models.append(forward_model)

# %%
path_cortex_low = os.path.join(base_path, 'tess_cortex_pial_low.mat')
cortex_low = scipy.io.loadmat( path_cortex_low )
cortex_low.keys()
pos_low = cortex_low["Vertices"]

path_cortex_high = os.path.join(base_path, 'tess_cortex_pial_high_50000V.mat')
cortex_high = scipy.io.loadmat( path_cortex_high )
cortex_high.keys()
pos_high = cortex_high["Vertices"]

forward_models[0]["pos"] = pos_low
forward_models[1]["pos"] = pos_high

# %% [markdown]
# ## Recompute inverse solution in python based on matlab data (in /savedata)

# %%
from scipy.spatial.distance import cdist
from scipy.sparse import csr_matrix
# solver_names = ["SSM", "AP", "RAP"]
solvers = {
    "SSM": Solver("SSM", scale_leadfield=False, prep_leadfield=False),
    "AP": Solver("AP", scale_leadfield=False, prep_leadfield=False),
    # "RAP": Solver("RAP-MUSIC", scale_leadfield=False, prep_leadfield=False),
}

files = r"C:\Users\lukas\OneDrive\Dokumente\projects\flex_ssm\code_amir\savedata"

data_files = [os.path.join(files,f) for f in os.listdir(files) if f.startswith("Y_")]
mean_localization_errors = {solver_name: [] for solver_name in solvers.keys()}

for i, data_file in enumerate(data_files):
    print(f"Sample {i}")
    eeg = scipy.io.loadmat(data_file)
    Y = eeg['Y']
    idc_ap = eeg['S_AP_sub'] - 1
    idc_ap = sorted(idc_ap[0].astype(int))

    idc_ssm = eeg['S_SSM'] - 1
    idc_ssm = sorted(idc_ssm[0].astype(int))

    _, model_idx, src_err, corr, _, mc_idx = os.path.split(data_file)[1].split("_")
    model_idx = int(model_idx)-1
    mc_idx = int(mc_idx.split(".")[0]) - 1
    src_err = int(src_err)
    corr = float(corr)/100

    leadfield = leadfields[model_idx]
    
    print(f"Matlab:\n\tAP: {idc_ap}\n\tSSM: {idc_ssm}")
    for solver_name in solvers.keys():
        solver = solvers[solver_name]
        solver.leadfields = [leadfield,]
        solver.leadfield = leadfield
        solver.gradients = [csr_matrix(np.identity(leadfield.shape[1])), ]
        # try:
        if solver_name == "SSM":
            solver.make_ssm(Y, n_sources + src_err, refine_solution=True, max_iter=5,)
        elif solver_name == "AP":
            solver.make_ap(Y, n_sources + src_err, n_sources + src_err, refine_solution=True, max_iter=6,)
        elif solver_name == "RAP":
            solver.make_flex(Y, n_sources + src_err, n_sources + src_err, 0, False, refine_solution=False, max_iter=1000,)
        else:
            AttributeError("Solver not found")
            
        idc_est = np.array(sorted([x[1] for x in solver.candidates]))
        print(f"{solver_name}:\n\tEstimated: {idc_est}")
# Out:
# Sample 0
# Matlab:
# 	AP: [3954, 4739]
# 	SSM: [3954, 4739]
# SSM:
# 	Estimated: [3954 4739]

# %% [markdown]
# # Full python eval with matlab forward models

# %% [markdown]
# ## Simulation

# %%
from invert.simulate import generator_simple
n_simulations = 25
generator_args = dict(
    batch_size=n_simulations, 
    corrs=(0.1, 0.1), 
    T=50, 
    n_sources=3, 
    SNR_range=(0,0),
    random_seed=42)

fwd = dict(sol=dict(data=leadfields[0]))
gen_test = generator_simple(fwd, **generator_args)
x_test, y_test, sim_info = gen_test.__next__()
print(x_test.shape, y_test.shape)
sim_info.head()
# Out:
# (25, 306, 50) (25, 15002, 50)
#    n_sources  amplitudes  snr  inter_source_correlations n_orders  \
# 0          3           1  0.0                        0.1   [0, 0]
# 1          3           1  0.0                        0.1   [0, 0]
# 2          3           1  0.0                        0.1   [0, 0]
# 3          3           1  0.0                        0.1   [0, 0]
# 4          3           1  0.0                        0.1   [0, 0]
#
#    diffusion_parameter  n_timepoints  n_timecourses  iid_noise
# 0                    0            50            inf       True
# 1                    0            50            inf       True
# 2                    0            50            inf       True
# 3                    0            50            inf       True
# 4                    0            50            inf       True

# %%
from invert.evaluate import shortest_dists_amir
from scipy.sparse import csr_matrix
from scipy.spatial.distance import cdist

solvers = {
    "SSM": Solver("SSM", scale_leadfield=False, prep_leadfield=False),
    "AP": Solver("AP", scale_leadfield=False, prep_leadfield=False),
    # "RAP": Solver("RAP-MUSIC", scale_leadfield=False, prep_leadfield=False),
}

source_errors = (-1, 0, 1)
pos_true = forward_models[0]["pos"]
results = []
for i_sim in range(n_simulations):
    x = x_test[i_sim]
    y = y_test[i_sim]
    idc_true = np.where( y[:, 0] != 0)[0]
    # print(idc_true)
    for forward_model in forward_models:
        leadfield = forward_model["leadfield"]
        pos_est = forward_model["pos"]
        
        for source_error in source_errors:

            for solver_name in solvers.keys():
                solver = solvers[solver_name]
                solver.leadfields = [leadfield,]
                solver.leadfield = leadfield
                solver.gradients = [csr_matrix(np.identity(leadfield.shape[1])), ]
                # try:
                if solver_name == "SSM":
                    solver.make_ssm(x, n_sources + source_error, refine_solution=True, max_iter=5,)
                elif solver_name == "AP":
                    solver.make_ap(x, n_sources + source_error, n_sources + source_error, refine_solution=True, max_iter=6,)
                elif solver_name == "RAP":
                    solver.make_flex(x, n_sources + source_error, n_sources + source_error, 0, False, refine_solution=False, max_iter=1000,)
                else:
                    AttributeError("Solver not found")
                    
                idc_est = np.array(sorted([x[1] for x in solver.candidates]))

                positions_estimated = pos_est[idc_est, :]
                positions_true = pos_true[idc_true, :]
                
                dists = cdist(positions_estimated, positions_true)
                mle = shortest_dists_amir(dists)

                d = dict(
                    mle=mle,
                    source_error=source_error,
                    solver_name=solver_name,
                    forward_model=forward_model["headmodel"],
                    n_sources=len(idc_true),
                    n_sources_est=len(idc_est),
                    idx_MC=i_sim,
                )
                print(d)
                results.append(d)

    #             break
    #         break
    #     break
    # break

# save
import pandas as pd
df = pd.DataFrame(results)
df["mle"] *= 1000

df.to_csv("results_matlab_fwd_model.csv", index=False)
# Out:
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 0}
# {'mle': 0.0020314116886505865, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 0}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 0}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 0}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 0}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 0}
# {'mle': 0.0018356699143275293, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 0}
# {'mle': 0.006242542608142901, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 0}
# {'mle': 0.0028246651841314, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 0}
# {'mle': 0.0035345001177338312, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 0}
# {'mle': 0.0028246651841314, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 0}
# {'mle': 0.004660328047375516, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 0}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 1}
# {'mle': 0.0027509842003123138, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 1}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 1}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 1}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 1}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 1}
# {'mle': 0.0016653380251497483, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 1}
# {'mle': 0.0024711851269795344, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 1}
# {'mle': 0.001992304376948543, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 1}
# {'mle': 0.0023550530604947804, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 1}
# {'mle': 0.0023550530604947804, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 1}
# {'mle': 0.0023550530604947804, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 1}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 2}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 2}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 2}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 2}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 2}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 2}
# {'mle': 0.001435438107497528, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 2}
# {'mle': 0.0013042135351722848, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 2}
# {'mle': 0.0021092401949051897, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 2}
# {'mle': 0.0021092401949051897, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 2}
# {'mle': 0.0013521633400707925, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 2}
# {'mle': 0.0013521633400707925, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 2}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 3}
# {'mle': 0.004199532722531328, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 3}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 3}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 3}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 3}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 3}
# {'mle': 0.00019474698163184318, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 3}
# {'mle': 0.004080348438354189, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 3}
# {'mle': 0.0008018928068789979, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 3}
# {'mle': 0.0008583456484940046, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 3}
# {'mle': 0.0008583456484940046, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 3}
# {'mle': 0.0008583456484940046, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 3}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 4}
# {'mle': 0.0020840960174057068, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 4}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 4}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 4}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 4}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 4}
# {'mle': 0.0046425071643158965, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 4}
# {'mle': 0.00977106145807917, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 4}
# {'mle': 0.00625881101967068, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 4}
# {'mle': 0.004812507881331308, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 4}
# {'mle': 0.00625881101967068, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 4}
# {'mle': 0.0035735077883014333, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 4}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 5}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 5}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 5}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 5}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 5}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 5}
# {'mle': 0.00198656942063796, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 5}
# {'mle': 0.0018404273545066132, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 5}
# {'mle': 0.0018148402838148536, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 5}
# {'mle': 0.0016943350474132445, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 5}
# {'mle': 0.0018148402838148536, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 5}
# {'mle': 0.0018148402838148536, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 5}
# {'mle': 0.00314571040575931, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 6}
# {'mle': 0.00314571040575931, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 6}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 6}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 6}
# {'mle': 0.002313601164115222, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 6}
# {'mle': 0.008618906453832599, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 6}
# {'mle': 0.004913548733324722, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 6}
# {'mle': 0.004913548733324722, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 6}
# {'mle': 0.004119645067191311, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 6}
# {'mle': 0.0014641146001727978, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 6}
# {'mle': 0.004119645067191311, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 6}
# {'mle': 0.0061411704424553315, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 6}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 7}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 7}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 7}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 7}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 7}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 7}
# {'mle': 0.0017797150334215048, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 7}
# {'mle': 0.006785947433824484, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 7}
# {'mle': 0.00396542530306764, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 7}
# {'mle': 0.004265976499933276, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 7}
# {'mle': 0.004142849401682821, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 7}
# {'mle': 0.0037270238947910914, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 7}
# {'mle': 0.005827495521761655, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 8}
# {'mle': 0.0031721022668393475, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 8}
# {'mle': 0.0008026697221766517, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 8}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 8}
# {'mle': 0.0008026697221766517, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 8}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 8}
# {'mle': 0.007359220181637226, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 8}
# {'mle': 0.015777610146522632, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 8}
# {'mle': 0.0030665769414219743, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 8}
# {'mle': 0.0010589664851406056, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 8}
# {'mle': 0.004401892063673839, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 8}
# {'mle': 0.0016942772800930053, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 8}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 9}
# {'mle': 0.006939090026196177, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 9}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 9}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 9}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 9}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 9}
# {'mle': 0.0053803408400601655, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 9}
# {'mle': 0.01227107122328942, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 9}
# {'mle': 0.011284935144659494, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 9}
# {'mle': 0.012010256884701379, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 9}
# {'mle': 0.009802191228025706, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 9}
# {'mle': 0.012010256884701379, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 9}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 10}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 10}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 10}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 10}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 10}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 10}
# {'mle': 0.002915165012979415, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 10}
# {'mle': 0.009475319803017992, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 10}
# {'mle': 0.002716913789723207, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 10}
# {'mle': 0.002716913789723207, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 10}
# {'mle': 0.002716913789723207, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 10}
# {'mle': 0.002716913789723207, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 10}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 11}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 11}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 11}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 11}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 11}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 11}
# {'mle': 0.005618687944124299, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 11}
# {'mle': 0.0037514347655238822, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 11}
# {'mle': 0.005053360890517386, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 11}
# {'mle': 0.005053360890517386, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 11}
# {'mle': 0.006298196342917665, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 11}
# {'mle': 0.005053360890517386, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 11}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 12}
# {'mle': 0.00064575144365225, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 12}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 12}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 12}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 12}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 12}
# {'mle': 0.0027271435483196657, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 12}
# {'mle': 0.0027377992528545623, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 12}
# {'mle': 0.0021969154845384218, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 12}
# {'mle': 0.0021969154845384218, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 12}
# {'mle': 0.0021969154845384218, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 12}
# {'mle': 0.002204019287561686, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 12}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 13}
# {'mle': 0.011510344698648372, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 13}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 13}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 13}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 13}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 13}
# {'mle': 0.003266108518684231, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 13}
# {'mle': 0.01081931973234947, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 13}
# {'mle': 0.0032675203314861834, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 13}
# {'mle': 0.0025886231967777065, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 13}
# {'mle': 0.0032675203314861834, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 13}
# {'mle': 0.002275275331205841, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 13}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 14}
# {'mle': 0.010958220248940716, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 14}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 14}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 14}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 14}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 14}
# {'mle': 0.0024898817040328973, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 14}
# {'mle': 0.011897197625390547, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 14}
# {'mle': 0.003221970164073136, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 14}
# {'mle': 0.003221970164073136, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 14}
# {'mle': 0.003221970164073136, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 14}
# {'mle': 0.003221970164073136, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 14}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 15}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 15}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 15}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 15}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 15}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 15}
# {'mle': 0.001881761476454605, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 15}
# {'mle': 0.001881761476454605, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 15}
# {'mle': 0.005477542568414931, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 15}
# {'mle': 0.005477542568414931, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 15}
# {'mle': 0.005752503789160678, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 15}
# {'mle': 0.0021317566679580915, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 15}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 16}
# {'mle': 0.012558591927873567, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 16}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 16}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 16}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 16}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 16}
# {'mle': 0.0012129579369318728, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 16}
# {'mle': 0.001706297332158592, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 16}
# {'mle': 0.002186021105111657, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 16}
# {'mle': 0.002186021105111657, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 16}
# {'mle': 0.002186021105111657, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 16}
# {'mle': 0.0024135490811480306, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 16}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 17}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 17}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 17}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 17}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 17}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 17}
# {'mle': 0.0010683543632058505, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 17}
# {'mle': 0.005579150532957839, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 17}
# {'mle': 0.0021487449906970875, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 17}
# {'mle': 0.0021487449906970875, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 17}
# {'mle': 0.0021487449906970875, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 17}
# {'mle': 0.0041538126437667576, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 17}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 18}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 18}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 18}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 18}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 18}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 18}
# {'mle': 0.0025788486218737095, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 18}
# {'mle': 0.00346140656922231, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 18}
# {'mle': 0.00295255686115235, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 18}
# {'mle': 0.00295255686115235, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 18}
# {'mle': 0.00295255686115235, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 18}
# {'mle': 0.00295255686115235, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 18}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 19}
# {'mle': 0.005488887620632014, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 19}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 19}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 19}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 19}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 19}
# {'mle': 0.0021449468928171835, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 19}
# {'mle': 0.005832808805587574, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 19}
# {'mle': 0.004173038994137566, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 19}
# {'mle': 0.004173038994137566, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 19}
# {'mle': 0.004173038994137566, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 19}
# {'mle': 0.004173038994137566, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 19}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 20}
# {'mle': 0.0027001682379939676, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 20}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 20}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 20}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 20}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 20}
# {'mle': 0.0031402997780928805, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 20}
# {'mle': 0.0037326878374021053, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 20}
# {'mle': 0.0035651099019094446, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 20}
# {'mle': 0.0026593632094414504, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 20}
# {'mle': 0.0035651099019094446, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 20}
# {'mle': 0.0015376667278868665, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 20}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 21}
# {'mle': 0.011563696946637298, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 21}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 21}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 21}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 21}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 21}
# {'mle': 0.0017777521136038655, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 21}
# {'mle': 0.013155466577362792, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 21}
# {'mle': 0.002141072732435459, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 21}
# {'mle': 0.0031349854336286103, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 21}
# {'mle': 0.002779037410652488, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 21}
# {'mle': 0.0031349854336286103, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 21}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 22}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 22}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 22}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 22}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 22}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 22}
# {'mle': 0.005769219106525585, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 22}
# {'mle': 0.005088211995265464, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 22}
# {'mle': 0.005561397785874754, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 22}
# {'mle': 0.005561397785874754, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 22}
# {'mle': 0.005561397785874754, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 22}
# {'mle': 0.005561397785874754, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 22}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 23}
# {'mle': 0.00782916730580632, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 23}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 23}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 23}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 23}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 23}
# {'mle': 0.002409425013531503, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 23}
# {'mle': 0.003793384046740922, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 23}
# {'mle': 0.0021957713573468774, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 23}
# {'mle': 0.002761977104810038, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 23}
# {'mle': 0.002761977104810038, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 23}
# {'mle': 0.001863192793052965, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 23}
# {'mle': 0.0, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 24}
# {'mle': 0.0029697392693925828, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 24}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 24}
# {'mle': 0.0, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 24}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 24}
# {'mle': 0.0, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_groundtruth_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 24}
# {'mle': 0.00650404618446044, 'source_error': -1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 24}
# {'mle': 0.003770975097182958, 'source_error': -1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 2, 'idx_MC': 24}
# {'mle': 0.0059521987624047736, 'source_error': 0, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 24}
# {'mle': 0.004739374111678228, 'source_error': 0, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 3, 'idx_MC': 24}
# {'mle': 0.0059521987624047736, 'source_error': 1, 'solver_name': 'SSM', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 24}
# {'mle': 0.004130151370886452, 'source_error': 1, 'solver_name': 'AP', 'forward_model': 'headmodel_surf_openmeeg_MEG_regrid_x_2mm_posterior_constrained', 'n_sources': 3, 'n_sources_est': 4, 'idx_MC': 24}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# load
# df = pd.read_csv("results_matlab_fwd_model.csv")
ylim = (0, 15)
new_x_labels = ["Original Headmodel",
          "Biased Headmodel (2mm posterior)"]
plt.figure(figsize=(13, 8))

# when source error == -1
plt.subplot(1, 3, 1)
df_ = df[df["source_error"] == -1]
sns.barplot(data=df_, hue="solver_name", y="mle", x="forward_model")
plt.xticks(rotation=45)
plt.ylabel("Mean Localization Error [mm]")
plt.xlabel("Headmodel")
plt.ylim(*ylim)
plt.xticks(range(2), new_x_labels)
plt.title("1 source less")

# when source error == 0
plt.subplot(1, 3, 2)
df_ = df[df["source_error"] == 0]
sns.barplot(data=df_, hue="solver_name", y="mle", x="forward_model")
plt.xticks(rotation=45)
plt.ylabel("Mean Localization Error [mm]")
plt.xlabel("Headmodel")
plt.ylim(*ylim)
plt.xticks(range(2), new_x_labels)
plt.title("Correct number of sources")
plt.legend().set_visible(False)

# when source error == 1
plt.subplot(1, 3, 3)
df_ = df[df["source_error"] == 1]
sns.barplot(data=df_, hue="solver_name", y="mle", x="forward_model")
plt.xticks(rotation=45)
plt.ylabel("Mean Localization Error [mm]")
plt.xlabel("Headmodel")
plt.ylim(*ylim)
plt.xticks(range(2), new_x_labels)
plt.title("1 source more")
plt.legend().set_visible(False)


plt.tight_layout()

# %%
df
# Out:
#           mle  source_error solver_name  \
# 0    0.000000            -1         SSM
# 1    2.031412            -1          AP
# 2    0.000000             0         SSM
# 3    0.000000             0          AP
# 4    0.000000             1         SSM
# ..        ...           ...         ...
# 295  3.770975            -1          AP
# 296  5.952199             0         SSM
# 297  4.739374             0          AP
# 298  5.952199             1         SSM
# 299  4.130151             1          AP
#
#                                          forward_model  n_sources  \
# 0    headmodel_surf_openmeeg_MEG_groundtruth_constr...          3
# 1    headmodel_surf_openmeeg_MEG_groundtruth_constr...          3
# 2    headmodel_surf_openmeeg_MEG_groundtruth_constr...          3
# 3    headmodel_surf_openmeeg_MEG_groundtruth_constr...          3
# 4    headmodel_surf_openmeeg_MEG_groundtruth_constr...          3
# ..                                                 ...        ...
# 295  headmodel_surf_openmeeg_MEG_regrid_x_2mm_poste...          3
# 296  headmodel_surf_openmeeg_MEG_regrid_x_2mm_poste...          3
# 297  headmodel_surf_openmeeg_MEG_regrid_x_2mm_poste...          3
# 298  headmodel_surf_openmeeg_MEG_regrid_x_2mm_poste...          3
# 299  headmodel_surf_openmeeg_MEG_regrid_x_2mm_poste...          3
#
#      n_sources_est  idx_MC
# 0                2       0
# 1                2       0
# 2                3       0
# 3                3       0
# 4                4       0
# ..             ...     ...
# 295              2      24
# 296              3      24
# 297              3      24
# 298              4      24
# 299              4      24
#
# [300 rows x 7 columns]
