# %%
import pickle as pkl
path = r"D:\data\flex_ssm\results\results_figure-1_Clean-Coarse_non-greedy.pkl"

with open(path, "rb") as f:
    results = pkl.load(f)

print(results[0])
# Out:
# {'Method': 'MCMV', 'mle_match': 0.0, 'Time_Make': 0.26593995094299316, 'Time_Apply': 0.1823287010192871, 'n_sources': 2, 'amplitudes': array([1., 1.]), 'snr': 0.0, 'inter_source_correlations': 0.1, 'n_orders': [0, 1], 'diffusion_parameter': 0.1, 'n_timepoints': 128, 'n_timecourses': 2000, 'correlation_mode': None, 'noise_color_coeff': 0.0}

# %%
import pandas as pd

df = pd.DataFrame(results)
display(df)
import matplotlib.pyplot as plt
import seaborn as sns

# bar plot
sns.barplot(x="inter_source_correlations", hue="Method", y="mle_match", data=df)
# Out:
#          Method  mle_match  Time_Make  Time_Apply  n_sources       amplitudes  \
# 0          MCMV   0.000000   0.265940    0.182329          2       [1.0, 1.0]
# 1          MCMV   0.000000   0.250891    0.166118          2       [1.0, 1.0]
# 2          MCMV   0.000000   0.266971    0.181297          2       [1.0, 1.0]
# 3          MCMV   0.000000   0.415397    0.422226          2       [1.0, 1.0]
# 4          MCMV   0.000000   0.490893    0.346837          2       [1.0, 1.0]
# ...         ...        ...        ...         ...        ...              ...
# 5595  Champagne  11.589710   3.863514    0.133472          3  [1.0, 1.0, 1.0]
# 5596  Champagne   7.579549   3.018739    0.139130          3  [1.0, 1.0, 1.0]
# 5597  Champagne  13.886274   3.813740    0.107972          3  [1.0, 1.0, 1.0]
# 5598  Champagne  58.382567   2.736681    0.143546          3  [1.0, 1.0, 1.0]
# 5599  Champagne  27.228597   4.112981    0.083505          3  [1.0, 1.0, 1.0]
#
# ...
